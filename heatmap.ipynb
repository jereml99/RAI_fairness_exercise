# %%
import pandas as pd

# Define the data
data = {
    "before mitigation": [0.769, 0.85, 0.244, 0.155, 0.62, 0.556, 0.222, 0.137],
    "mitigate(constr=eq_odds)": [0.678, 0.643, 0.345, 0.377, 0.705, 0.73, 0.323, 0.361],
    "mitigate(constr=Indep)": [0.76, 0.746, 0.253, 0.273, 0.624, 0.747, 0.232, 0.253],
    "distort_0.3_test(constr=eq_odds)": [0.678, 0.564, 0.345, 0.377, 0.705, 0.41, 0.323, 0.36],
    "distort_0.3_test(constr=Indep)": [0.76, 0.606, 0.253, 0.274, 0.624, 0.317, 0.232, 0.274],
    "distort_0.3_test_0.1_val(constr=eq_odds)": [0.523, 0.503, 0.493, 0.548, 0.641, 0.576, 0.484, 0.533],
    "distort_0.3_test_0.1_val(constr=Indep)": [0.655, 0.545, 0.37, 0.427, 0.726, 0.458, 0.349, 0.412],
    "distort_0.3_test_0.3_val(constr=eq_odds)": [0.386, 0.449, 0.639, 0.675, 0.726, 0.689, 0.634, 0.669],
    "distort_0.3_test_0.3_val(constr=Indep)": [0.655, 0.566, 0.37, 0.404, 0.726, 0.454, 0.35, 0.379],
}

# Define the index (rows)
index = [
    "accuracy-0", "accuracy-1", "selection_rate-0", "selection_rate-1", 
    "TPR-0", "TPR-1", "FPR-0", "FPR-1"
]

# Create the dataframe
df = pd.DataFrame(data, index=index)

# %%
df
# Out:
#                   before mitigation  mitigate(constr=eq_odds)  \
# accuracy-0                    0.769                     0.678
# accuracy-1                    0.850                     0.643
# selection_rate-0              0.244                     0.345
# selection_rate-1              0.155                     0.377
# TPR-0                         0.620                     0.705
# TPR-1                         0.556                     0.730
# FPR-0                         0.222                     0.323
# FPR-1                         0.137                     0.361
#
#                   mitigate(constr=Indep)  distort_0.3_test(constr=eq_odds)  \
# accuracy-0                         0.760                             0.678
# accuracy-1                         0.746                             0.564
# selection_rate-0                   0.253                             0.345
# selection_rate-1                   0.273                             0.377
# ...

# %%
import seaborn as sns

sns.heatmap(df, annot=True, square=True, linewidths=0.01,cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: >
